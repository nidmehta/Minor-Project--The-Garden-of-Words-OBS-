# %%
import cv2

# %%
cam = cv2.VideoCapture(0)

# %%
cv2.namedWindow("test")

# %%
img_counter = 0
img_name = 0
while True:
    ret, frame = cam.read()
    if not ret:
        print("failed to grab frame")
        break
    cv2.imshow("test", frame)

    k = cv2.waitKey(1)
    if k%256 == 27:  #ESC 
        print("Escape hit, closing...")
        break
    elif k%256 == 32:  #SPACE 
        img_name = "opencv_frame_{}.png".format(img_counter)
        cv2.imwrite(img_name, frame)
        print("{} written!".format(img_name))
        img_counter += 1

cam.release()

cv2.destroyAllWindows()
# Out:
# opencv_frame_0.png written!
# Escape hit, closing...

# %%
img = cv2.imread(img_name)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray, 1.1, 4)

#To draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 1)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
from deepface import DeepFace

# %%
predictions = DeepFace.analyze(img, enforce_detection=False)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:07<00:00,  1.93s/it]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.010574781675988758,
#   'disgust': 6.935401647775084e-07,
#   'fear': 0.5542668318877421,
#   'happy': 80.95218766305594,
#   'sad': 0.1964377470835749,
#   'surprise': 0.78611345903713,
#   'neutral': 17.5004118680463},
#  'dominant_emotion': 'happy',
#  'region': {'x': 197, 'y': 138, 'w': 160, 'h': 160},
#  'age': 35,
#  'gender': 'Woman',
#  'race': {'asian': 1.3894506936430104,
#   'indian': 2.110574701657927,
#   'black': 0.24016410509030758,
#   'white': 37.79810514472662,
#   'middle eastern': 9.110561417274306,
#   'latino hispanic': 49.35114093409289},
#  'dominant_race': 'latino hispanic'}

# %%
dominantEmotion = predictions['dominant_emotion']

# %%
print("You seem to be mostly", dominantEmotion)
# Out:
# You seem to be mostly happy

# %%
import webbrowser
chrome_path = 'C:/Program Files (x86)/Google/Chrome/Application/chrome.exe %s'
print("So what kind of books would you prefer to read?")
print("1. Fiction")
print("2. Non-fiction")
n1 = int(input("Choose an option (1 - 2): "))
if n1 == 1:
    print("So what genre of fiction books would you prefer to read?")
    print("1. Action/Adventure")
    print("2. Children/Comic")
    print("3. Crime/Mystery/Thriller")
    print("4. Drama/Fairytales/Folktales")
    print("5. Science Fiction")
    print("6. Young Adult/Romance/Chick-Lit")
    n2 = int(input("Choose an option (1 - 6): "))
    
    if n2 == 1:
        print("Redirecting you to Action/Adventure (Fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/action')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/adventure')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/shelf/show/action-adventure-fiction')     
    elif n2 == 2:
        print("Redirecting you to Children/Comic (Fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/search?utf8=%E2%9C%93&q=harry+potter&search_type=books')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/search?utf8=%E2%9C%93&q=comic+children&search_type=books')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/search?utf8=%E2%9C%93&q=diary+of+a+wimpy+kids&search_type=books')
    elif n2 == 3:
        print("Redirecting you to Crime/Mystery/Thriller (Fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/thriller')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/mystery')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/crime')
    elif n2 == 4:
        print("Redirecting you to Drama/Fairytales/Folktales (Fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/drama')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/shelf/show/fairy-tales')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/folk-tales')
    elif n2 == 5:
        print("Redirecting you to Science Fiction (Fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/science-fiction')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/planetary-romance')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/time-travel')
    elif n2 == 6:
        print("Redirecting you to Young Adult/Romance/Chick-Lit (Fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/romance')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/chick-lit')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/young-adult')
    else:
        print("Redirecting you to fiction books to read when you're not really sure how you're feeling...")
        webbrowser.get(using = chrome_path).open('https://www.goodreads.com/shelf/show/feel-good-fiction')

elif n1 == 2:
    print("So what genre of non-fiction books would you prefer to read?")
    print("1. Autobiography/Biography/Memoir")
    print("2. History")
    print("3. Philosophy")
    print("4. Religious/Spiritual")
    print("5. True Crime")
    n2 = int(input("Choose an option (1 - 5): "))
    
    if n2 == 1:
        print("Redirecting you to Autobiography/Biography (Non-fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/autobiography')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/biography')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/memoir')
    elif n2 == 2:
        print("Redirecting you to History (Non-fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/history')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/food-history')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/prehistory')
    elif n2 == 3:
        print("Redirecting you to Philosophy (Non-fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/philosophy')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/thelema')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/metaphysics')
    elif n2 == 4:
        print("Redirecting you to Religious/Spiritual (Non-fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/religion')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/belief')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/genres/faith')
    elif n2 == 5:
        print("Redirecting you to True Crime (Non-fiction) books to read when you're feeling", dominantEmotion, "...")
        if dominantEmotion == 'happy':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/list/show/903.Best_True_Crime')
        elif dominantEmotion == 'sad':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/list/show/162958.Nonviolent_True_Crime_')
        elif dominantEmotion == 'neutral':
            webbrowser.get(using = chrome_path).open('https://www.goodreads.com/blog/show/1207-20-top-rated-true-crime-books-on-goodreads')
    else:
        print("Redirecting you to non-fiction books to read when you're not really sure how you're feeling...")
        webbrowser.get(using = chrome_path).open('https://www.goodreads.com/shelf/show/feel-good-non-fiction') 
        
else:
    print("Redirecting you to books to read when you're not really sure how you're feeling...")
    webbrowser.get(using = chrome_path).open('https://www.goodreads.com/list/tag/feel-good')
# Out:
# So what kind of books would you prefer to read?
# 1. Fiction
# 2. Non-fiction
# Choose an option (1 - 2): 1
# So what genre of fiction books would you prefer to read?
# 1. Action/Adventure
# 2. Children/Comic
# 3. Crime/Mystery/Thriller
# 4. Drama/Fairytales/Folktales
# 5. Science Fiction
# 6. Young Adult/Romance/Chick-Lit
# Choose an option (1 - 6): 2
# Redirecting you to Children/Comic (Fiction) books to read when you're feeling happy ...
